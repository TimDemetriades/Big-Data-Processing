# %% [markdown]
# # HW 4 - Tim Demetriades
# ## Feature Selection
# ### Using the top 3 features here.
# March 12th, 2021

# %%
import pandas as pd                 # for dataframes
import numpy as np                  # for arrays 
import matplotlib.pyplot as plt     # for plots
from sklearn import metrics         # for regression/roc
from sklearn.linear_model import LogisticRegression    # for regression model
from sklearn.feature_selection import RFE              # for rfe feature selection

# %%
# Read data
df = pd.read_csv('dataSet_2.csv', header=None)
df
# Out:
#           0        1        2        3        4        5       6       7    \
# 0     1.85050  0.44413 -0.26072 -0.92156 -0.52009  2.73230 -1.5232 -1.2479
# 1     2.13930  0.67815 -0.34487 -0.93527 -0.52009  3.08680 -1.5549 -1.2048
# 2     2.19670  0.63249 -0.28908 -0.89806 -0.52009  3.08970 -1.5624 -1.1764
# 3     2.21590  0.68735 -0.31650 -0.90001 -0.52009  3.15650 -1.5627 -1.0686
# 4     2.26450  0.69541 -0.31650 -0.93331 -0.52009  3.09840 -1.5769 -1.1232
# ...       ...      ...      ...      ...      ...      ...     ...     ...
# 5917 -0.49460  0.25691  1.60670  1.64210  1.92240  0.24546  1.9545  1.6000
# 5918 -0.48429  0.29911  1.63510  1.67340  1.92240  0.26870  1.9817  1.6059
# 5919 -0.43715  0.28530  1.66250  1.68120  1.92240  0.29775  2.0059  1.6073
# 5920 -0.47545  0.31983  1.60670  1.71850  1.92240  0.26289  2.0425  1.6059
# 5921 -0.46514  0.28339  1.60670  1.73220  1.92240  0.26579  2.0516  1.6146
#
#          8        9    ...       914       915       916       917       918  \
# 0     1.4870 -0.52449  ... -0.403160 -0.555010 -0.590640 -0.631990 -0.717270
# 1     1.4753 -0.41132  ... -1.182500  1.527000  0.267590  2.798700  0.147000
# 2     1.5184 -0.37138  ...  0.258950 -0.537660  1.899500  0.568590 -0.992550
# 3     1.5353 -0.34309  ...  1.780200  2.820300  0.268560 -0.150870  0.241210
# 4     1.4557 -0.32478  ... -0.991740 -0.520880 -0.426940  0.506380  0.355670
# ...      ...      ...  ...       ...       ...       ...       ...       ...
# 5917  1.6307  2.14820  ... -0.132260 -0.004755 -0.801210  0.042059 -0.406010
# 5918  1.6307  2.15980  ...  1.373600 -0.004755  0.982660  0.094923  1.378600
# 5919  1.6424  2.20810  ... -0.898300 -0.004755 -0.693790  1.147100  0.633700
# 5920  1.6816  2.20140  ... -0.971120 -0.004755  0.982660 -0.987020 -0.979740
# 5921  1.6660  2.23140  ...  0.003648 -0.004755  0.000621 -0.001171 -0.002969
#
#            919       920      921       922  923
# 0    -0.643510 -0.807630 -0.27966 -0.160250    1
# 1     2.835500  0.153120  0.80599  0.859200    1
# 2     0.192200 -0.031013  0.69062  1.500700    1
# 3    -0.171270  0.292480  1.05210 -0.389050    1
# 4    -0.004882 -0.669040  0.43659  0.230740    0
# ...        ...       ...      ...       ...  ...
# 5917  0.091662  0.730800  0.45714  0.151720    1
# 5918  1.367900  1.516800 -0.14857  0.169040    1
# 5919  0.520360 -1.208600  0.54000  0.759190    1
# 5920 -0.977890  0.984770 -0.87906 -0.865510    1
# 5921 -0.004982 -0.001137 -0.01269  0.006641    1
#
# [5922 rows x 924 columns]

# %%
# Split data by predictor and response
predictor = df.iloc[:, 0:923]
response = df[923]

# %% [markdown]
# Each column in predictor is a time series. We will compute the daily change rate using the formula **[X(t)- X(t-1)]/X(t-1)** to generate a new predictor matrix. Note that this will remove the first row of data.

# %%
new_predictor = (predictor[1:].to_numpy() - predictor[:5921]) / predictor[:5921]
new_predictor
# Out:
#            0         1         2         3    4         5         6    \
# 0     0.156066  0.526918  0.322760  0.014877 -0.0  0.129744  0.020811
# 1     0.026831 -0.067330 -0.161771 -0.039785 -0.0  0.000939  0.004823
# 2     0.008740  0.086737  0.094853  0.002171 -0.0  0.021620  0.000192
# 3     0.021932  0.011726 -0.000000  0.037000 -0.0 -0.018406  0.009087
# 4    -0.021462 -0.035303  0.176272  0.048258 -0.0 -0.015944  0.008942
# ...        ...       ...       ...       ...  ...       ...       ...
# 5916 -0.017559  0.021348  0.000000  0.004834  0.0 -0.086491 -0.003315
# 5917 -0.020845  0.164260  0.017676  0.019061  0.0  0.094679  0.013917
# 5918 -0.097338 -0.046170  0.016757  0.004661  0.0  0.108113  0.012212
# 5919  0.087613  0.121030 -0.033564  0.022187  0.0 -0.117078  0.018246
# 5920 -0.021685 -0.113936  0.000000  0.007972  0.0  0.011031  0.004455
#
#            7         8         9    ...       913        914       915  \
# 0    -0.034538 -0.007868 -0.215772  ... -3.443194   1.933079 -3.751302
# 1    -0.023572  0.029214 -0.097102  ... -1.326560  -1.218985 -1.352102
# 2    -0.091635  0.011130 -0.076175  ... -9.176560   5.874686 -6.245508
# 3     0.051095 -0.051847 -0.053368  ... -1.631403  -1.557095 -1.184690
# 4     0.049769 -0.025143  0.030759  ... -0.726210  -2.002561  0.226348
# ...        ...       ...       ...  ...       ...        ...       ...
# 5916  0.006923 -0.013431 -0.002322  ... -1.817945  -0.811276 -0.000000
# 5917  0.003688  0.000000  0.005400  ... -2.222577 -11.385604 -0.000000
# 5918  0.000872  0.007175  0.022363  ... -1.708467  -1.653975 -0.000000
# 5919 -0.000871  0.023868 -0.003034  ... -2.411499   0.081064 -0.000000
# 5920  0.005418 -0.009277  0.013628  ... -1.000795  -1.003756 -0.000000
#
#            916        917       918         919        920       921       922
# 0    -1.453051  -5.428393 -1.204944   -5.406303  -1.189592 -3.882035 -6.361622
# 1     6.098546  -0.796838 -7.752041   -0.932217  -1.202540 -0.143141  0.746625
# 2    -0.858615  -1.265341 -1.243021   -1.891103 -10.430884  0.523414 -1.259246
# 3    -2.589738  -4.356400  0.474524   -0.971494  -3.287473 -0.585030 -1.593086
# 4    -5.586827  -3.221257 -3.726347  209.658911  -1.110787 -4.197050 -3.602670
# ...        ...        ...       ...         ...        ...       ...       ...
# 5916 -1.815348  -1.078885  0.109984   -1.052345  -1.669906 -1.416036 -1.104953
# 5917 -2.226470   1.256901 -4.395483   13.923305   1.075534 -1.324999  0.114158
# 5918 -1.706033  11.084532 -0.540331   -0.619592  -1.796809 -4.634650  3.491186
# 5919 -2.416365  -1.860448 -2.546063   -2.879257  -1.814802 -2.627889 -2.140044
# 5920 -0.999368  -0.998814 -0.996970   -0.994906  -1.001155 -0.985564 -1.007673
#
# [5921 rows x 923 columns]

# %% [markdown]
# We then add these new values to the respective values in the original predictor matrix (minus the first row).

# %%
new_predictor = new_predictor + predictor[1:].to_numpy()
new_predictor
# Out:
#            0         1         2         3        4         5         6    \
# 0     2.295366  1.205068 -0.022110 -0.920393 -0.52009  3.216544 -1.534089
# 1     2.223531  0.565160 -0.450851 -0.937845 -0.52009  3.090639 -1.557577
# 2     2.224640  0.774087 -0.221647 -0.897839 -0.52009  3.178120 -1.562508
# 3     2.286432  0.707136 -0.316500 -0.896310 -0.52009  3.079994 -1.567813
# 4     2.194438  0.635557 -0.196018 -0.930092 -0.52009  3.033056 -1.582058
# ...        ...       ...       ...       ...      ...       ...       ...
# 5916 -0.512159  0.278258  1.606700  1.646934  1.92240  0.158969  1.951185
# 5917 -0.505135  0.463370  1.652776  1.692461  1.92240  0.363379  1.995617
# 5918 -0.534488  0.239130  1.679257  1.685861  1.92240  0.405863  2.018112
# 5919 -0.387837  0.440860  1.573136  1.740687  1.92240  0.145812  2.060746
# 5920 -0.486825  0.169454  1.606700  1.740172  1.92240  0.276821  2.056055
#
#            7         8         9    ...       913        914       915  \
# 0    -1.239338  1.467432 -0.627092  ... -2.479574   0.750579 -2.224302
# 1    -1.199972  1.547614 -0.468482  ... -1.641240  -0.960035 -1.889762
# 2    -1.160235  1.546430 -0.419265  ... -6.603560   7.654886 -3.425208
# 3    -1.072105  1.403853 -0.378148  ... -3.256003  -2.548835 -1.705570
# 4    -1.129331  1.393957 -0.304011  ... -1.171010  -1.008281 -0.412432
# ...        ...       ...       ...  ...       ...        ...       ...
# 5916  1.606923  1.617269  2.145878  ... -1.015525  -0.943536 -0.004755
# 5917  1.609588  1.630700  2.165200  ... -3.203597 -10.012004 -0.004755
# 5918  1.608172  1.649575  2.230463  ... -1.013447  -2.552275 -0.004755
# 5919  1.605029  1.705468  2.198366  ... -3.392519  -0.890056 -0.004755
# 5920  1.620018  1.656723  2.245028  ... -1.000015  -1.000108 -0.004755
#
#            916        917       918         919        920       921       922
# 0    -1.185461  -2.629693 -1.057944   -2.570803  -1.036472 -3.076045 -5.502422
# 1     7.998046  -0.228248 -8.744591   -0.740017  -1.233553  0.547479  2.247325
# 2    -0.590055  -1.416211 -1.001811   -2.062373 -10.138404  1.575514 -1.648296
# 3    -3.016678  -3.850020  0.830194   -0.976376  -3.956513 -0.148440 -1.362346
# 4    -3.628527  -4.346057 -4.696027  208.630411  -1.036666 -5.592850 -4.203210
# ...        ...        ...       ...         ...        ...       ...       ...
# 5916 -2.616558  -1.036826 -0.296026   -0.960683  -0.939106 -0.958896 -0.953233
# 5917 -1.243810   1.351824 -3.016883   15.291205   2.592334 -1.473569  0.283198
# 5918 -2.399823  12.231632  0.093369   -0.099232  -3.005409 -4.094650  4.250376
# 5919 -1.433705  -2.847468 -3.525803   -3.857147  -0.830032 -3.506949 -3.005554
# 5920 -0.998747  -0.999985 -0.999939   -0.999887  -1.002292 -0.998254 -1.001032
#
# [5921 rows x 923 columns]

# %% [markdown]
# We must now also remove the first row from response.

# %%
new_response = response.iloc[1:]

# %% [markdown]
# We now create the model.

# %%
# Instantiate (create an instance of) the model
logreg = LogisticRegression(solver='liblinear', C=10.0, random_state=0, max_iter=8000)
# Fit the model with the data
logreg.fit(new_predictor, new_response)
# Predict the probability
y_pred_prob = logreg.predict_proba(new_predictor)[::, 1]    # this holds the probabilities for each row

# %% [markdown]
# This model took many iterations to converge. This is likely due to having too many features / overfitting which we will try to fix shortly. Let's now plot the model and caluclate the AUC.

# %%
fpr, tpr, _ = metrics.roc_curve(new_response, y_pred_prob)
auc = metrics.roc_auc_score(new_response, y_pred_prob)
plt.plot(fpr, tpr, label='HW4, AUC='+str(auc))
plt.legend(loc=4)

# For drawing a diagonal line y=x for reference
x = [0, 1]
y = [0, 1]
plt.plot(x, y)

plt.title('ROC Curve')
plt.xlabel('False Positive')
plt.ylabel('True Positive')

plt.show()

# %% [markdown]
# This model looks pretty solid with a relatively good AUC of 0.816. Let's now split the data into training and testing data to see how well it does.

# %%
predictor_train = new_predictor.iloc[0:4500, :]    # first 4500 rows and all columns except last
predictor_test = new_predictor.iloc[4500:, :]      # last 3000 rows and all columns except last
response_train = new_response.iloc[0:4500]       # first 3000 rows and last column
response_test = new_response.iloc[4500:]         # last 3000 rows and last column

# %%
# Instantiate (create an instance of) the model (using the default parameters)
logreg_train = LogisticRegression(solver='liblinear', C=10.0, random_state=0, max_iter=8000)
# Fit the model with the data
logreg_train.fit(predictor_train, response_train)
# Predict the probability
y_pred_prob_train = logreg_train.predict_proba(predictor_train)[::, 1]    # this holds the probabilites for each training row
y_pred_prob_test = logreg_train.predict_proba(predictor_test)[::, 1]      # using same model get probabilities for each testing row

# %%
fpr_train, tpr_train, _ = metrics.roc_curve(response_train, y_pred_prob_train)
fpr_test, tpr_test, _ = metrics.roc_curve(response_test, y_pred_prob_test)
auc_train = round(metrics.roc_auc_score(response_train, y_pred_prob_train), 3)
auc_test = round(metrics.roc_auc_score(response_test, y_pred_prob_test), 3)
plt.plot(fpr_train, tpr_train, label='HW4 - Train, AUC='+str(auc_train))
plt.plot(fpr_test, tpr_test, label='HW4 - Test, AUC='+str(auc_test))
plt.legend(loc=4)

# For drawing a diagonal line y=x for reference
x = [0, 1]
y = [0, 1]
plt.plot(x, y)

plt.title("ROC Curve")
plt.xlabel("False Positive")
plt.ylabel("True Positive")

plt.show()

# %%
auc_dif = auc_train - auc_test
print(f'Difference is auc values is {round(auc_dif, 3)}')
# Out:
# Difference is auc values is 0.301

# %% [markdown]
# Now let's use Recursive Feature Elimination (RFE) to eliminate some less important features.
#
# We'll try taking the top 3 features.
#
# Note - this took very long (around a day).

# %%
# Instantiate (create an instance of) the model (using the default parameters)
logreg_train = LogisticRegression(solver='liblinear', C=10.0, random_state=0, max_iter=8000)

rfe = RFE(logreg_train, 3)
fit = rfe.fit(predictor_train, response_train)
print("Num Features: %d" % fit.n_features_)
print("Selected Features: %s" % fit.support_)
print("Feature Ranking: %s" % fit.ranking_)
# Out:
# Num Features: 3
# Selected Features: [False False False False False False  True False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False  True
#  False False False  True False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False]
# Feature Ranking: [506 167  20 264  10  49   1 117 233  95  56 270  22   7   2 618 634 223
#  529 112 695  91  70  28   4 240  26   5  50 736 522  90   8  19  27   3
#   14 182 766  57  41 501  29  17 864  36 263 859 216  59  31  30 106 846
#   82  21 109  35 212 102  15 405  45  94  89 321  83   6  34  23   9 354
#  161 519 591 555 735 742 856 323 762  11  38   1  62  12  39   1  61 116
#  159  65 111 416 139 804 214 512 315 412 209 176 273  96 423 297 295 250
#  331 560  88 635  99 775 904 178 379 842 877 330 387 162 768 143 311 540
#  682 335 683 495 179 100 218 324 658 383 685 458 203 744 245 357 875 468
#  314 101 131 171 217 401 346 185 628 415 284 350 229 569 140 278 150 673
#  612 413 577 473 686 237 403 551 193 157 170 776 358 774 563 365 304 620
#  103 254 453 146  74 309  73 114 845 285 197 499 721 137 709 200 517 820
#  520 714 858 225 647 121 261 253 769 699 648 436 328 127 374 575  86  60
#  107 224 604 359 141 186 194 670 246 913 166 126 341 706 135 707 657 235
#  605 249 725  93 265 122 242 202 211 419 259 189 205 456 149 664 369 818
#  187 232 587 817 222 451 749 539 289 730 863 901 267 183  64  18 857 490
#  215 154 733 266 677 753 764 810 213 622 831 896 813 661 874 485 385 702
#  163 441 108 177 802  76 165  92 243 417 779 293 832 410 118 411 368 478
#  280 188 252 561 789 340 824 356 364 164 434 288 151 251 534 376 201 306
#  785 572 110 152 195 646 442 745 299 650 763 665 397 169 241 160 168 426
#  125 837 120 660  46 396 738 610 228 502 298 406  97 130  85 797 134 777
#  219 889 300 500 303 851 866 466 916 638 156 508 128  63 210 355  54 786
#  511 778 230 573 643 807 105 326 198 433 861 440 848 175 806 491 474 123
#  668  53  87  43  69 320 196 257 641 132 398 477 282 838 537 720 172 830
#  420 719 319  55  40  16  25 541 796 523 564 734 486 148 239 389 760 510
#  124 138 220 173 579 334  47 192  98  51  13  24 206 391 424 840 729 535
#  713 850 290 283 465 226 310 852 625 614 287 308 476 312 402 144 208 366
#  238 726 136 684 337 373 279 487 698 787 609 174 795  32  42 651 381 129
#  227 313  75 147 615 531 667 822 885 408 805  58 204  33 115  48 345 145
#   79 275 899 142 301 190 377 104 113 236 367 395 221 248  37  84 155 207
#   78 593  52  66 119 380 680 333 361 414 191 546 432 545 447 347 644 629
#  435  77  44 133 773 627 158 467 472 870 619 755 153 633 781 886 687  72
#  181  67  81  71 180  68  80 590 791 378 363 497 917 578 636 630 583 783
#  554 906 568 351 438 332 747 184 471 462 272 336 344 887 900 836 717 421
#  823 910 542 566 780 921 912 505 536 384 533 624 821 649 825 307 515 754
#  826 234 291 479 811 694 382 399 488 271 404 809 594 905 767 452 794 574
#  681 750 617 585 550 639 637 601 862 894 513 882 450 727 504 549 494 262
#  722 296 470 711 596 854 655 556 538 607 258 247 691 800 514 527 544 526
#  860 663 880 793 570 731 475 386 532 808 724 393 654 879 671 888 422 876
#  834 489 919 372 883 231 199 469 338 430 632 758 739 608 784 752 849 674
#  716 756 318 915 705 255 675 448 305 645 445 873 907 672 701 792 827 286
#  584 552 459 597 798 493 362 565 375 708 481 457 484 325 437 606 829 480
#  603 595 581 599 352 360 547 392 327 268 370 770 843 592 571 613 394 676
#  483 530 329 256 521 688 586 461 828 833 631 814 616 751 678 623 281 728
#  893 621 503 740 881 611 652 640 669 759 642 353 407 884 400 697 518 890
#  349 679 891 816 908 853 260 653 292 322 446 525 317 847 269 567 844 580
#  463 865 704 897 656 690 662 788 516 343 748 302 765 898 425 418 390 895
#  342 771 464 772 388 761 803 277 524 482 339 576 428 903 543 588 449 757
#  557 558 868 799 700 507 562 718 746 741 431 855 582 920 439 626 902 348
#  460 835 429 492 274 732 715 427 455 812 839 528 553 914 743 703 689 790
#  712 892 782 598 692 815 871 498 559 918 496 696 693 659 371 444 909 509
#  911 454 723 443 819 548 589 602 294 244 276 872 801 666 869 710 737 600
#  878 409 867 841 316]

# %%
# Predict the probability
y_pred_prob_train_rfe = fit.predict_proba(predictor_train)[::, 1]    # this holds the probabilites for each training row
y_pred_prob_test_rfe = fit.predict_proba(predictor_test)[::, 1]      # using same model get probabilities for each testing row

# %%
fpr_train, tpr_train, _ = metrics.roc_curve(response_train, y_pred_prob_train_rfe)
fpr_test, tpr_test, _ = metrics.roc_curve(response_test, y_pred_prob_test_rfe)
auc_train = round(metrics.roc_auc_score(response_train, y_pred_prob_train_rfe), 3)
auc_test = round(metrics.roc_auc_score(response_test, y_pred_prob_test_rfe), 3)
plt.plot(fpr_train, tpr_train, label='HW4 (RFE - 3 Features) - Train, AUC='+str(auc_train))
plt.plot(fpr_test, tpr_test, label='HW4 (RFE - 3 Features) - Test, AUC='+str(auc_test))
plt.legend(loc=4)

# For drawing a diagonal line y=x for reference
x = [0, 1]
y = [0, 1]
plt.plot(x, y)

plt.title("ROC Curve")
plt.xlabel("False Positive")
plt.ylabel("True Positive")

plt.show()

# %%
auc_dif = auc_train - auc_test
print(f'Difference is auc values is {round(auc_dif, 3)}')
# Out:
# Difference is auc values is 0.005

# %% [markdown]
# From what we can see here, the training did very well compared to the testing, which is good. However, both graphs have relatively bad ROC curves since both are around the diagonal line and we want them to be towards the top left of the graph. In the second part (HW 4 - 2) I try the same data with the top 10 features (instead of 3).
